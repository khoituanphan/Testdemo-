# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 3 * np.pi,0.1)
y = np.sin(x)

plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 3 * np.pi,0.1)

y_sin = np.sin(x)
y_cos = np.cos(x)

plt.plot(x,y_sin)
plt.plot(x, y_cos)

plt.xlabel("X")
plt.ylabel("Y")

plt.legend(["sine", "cos", "Tan"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 10,0.1)

fx = np.exp(-x/10)*np.sin(np.pi*x)
gx = x*(np.exp(-x/3))

plt.plot(x,fx)
plt.plot(x, gx)

plt.xlabel("X")
plt.ylabel("Y")

plt.legend(["sine", "cos", "Tan"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data_import = pd.read_csv("company_sales_data.csv")
x_data = data_import["month_number"]
y_data = data_import["total_profit"]


plt.xlabel("Month number")
plt.ylabel("Total Profit (10.000)")
plt.title ("Company Sales")

y = y_data/10000

plt.plot(x_data,y)
plt.show

print(data_import)
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
